# %% [markdown]
# <a href="https://colab.research.google.com/github/juan-123456/tareapy/blob/quintatanda/ejercicio8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#generamos nuestras librerias en este caso necesitamos de las 3 porque las nos 
#dice que debe permitir añadir y eliminar si es necesario

import pandas as pd
import numpy as np
import datetime as dt

# generamos nuestra funcion con los 4 csv invocados desde el github que se subieron
import pandas as pd 

csv1 = pd.read_csv('https://raw.githubusercontent.com/juan-123456/tareapy/quintatanda/emisiones-2016%201.csv', sep = ';')
csv2 = pd.read_csv('https://raw.githubusercontent.com/juan-123456/tareapy/quintatanda/emisiones-2017.csv', sep = ';')
csv3 = pd.read_csv('https://raw.githubusercontent.com/juan-123456/tareapy/quintatanda/emisiones-2018%201.csv', sep = ';')
csv4 = pd.read_csv('https://raw.githubusercontent.com/juan-123456/tareapy/quintatanda/emisiones-2019%201.csv', sep = ';')
#despues simplemente desplegamos los dataframe
vari = pd.concat([csv1, csv2, csv3, csv4])
vari
# Out:
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD  ...    D30  V30   D31  V31
# 0            28         79         4         1  ...    9.0    V   9.0    V
# 1            28         79         4         1  ...    0.0    N   0.0    N
# 2            28         79         4         1  ...   10.0    V   8.0    V
# 3            28         79         4         1  ...    8.0    V   0.0    N
# 4            28         79         4         1  ...    7.0    V   7.0    V
# ...         ...        ...       ...       ...  ...    ...  ...   ...  ...
# 1831         28         79        60        14  ...  108.0    V  98.0    V
# 1832         28         79        60        14  ...   55.0    V   0.0    N
# 1833         28         79        60        14  ...   19.0    V  47.0    V
# 1834         28         79        60        14  ...   56.0    V   0.0    N
# 1835         28         79        60        14  ...    5.0    V   4.0    V
#
# [7266 rows x 69 columns]
